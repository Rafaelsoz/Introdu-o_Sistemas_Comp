# %%
#LOAD INDEX
#STORE INDEX
#STORE

# %%
'''LOAD INDEX''' 
#BUSCA
selM! = sPC
RW = 0
IncPC = 1
LoadIR = 1

#DECODIFICAÇÃO / EXECUÇÃO
selM4 = Ry
selM1 = sM4
RW = 0
selM2 = sDATA_OUT
LoadReg[rx] = 1

# %%
'''STORE INDEX'''
#BUSCA
selM1 = sPC
RW = 0
lncPC = 1
LoadIR = 1

#DECOD / EXE
selM3 = Ry
selM5 = sM3
RW = 1
selM4 = Rx
selM1 = sM4

#DIFERENÇA ENTRE MUX 5 e MUX 1

# %%
'''STORE'''
#BUSCA
selM1 = sPC
RW = 0
lncPC = 1
LoadIR = 1

#DECOD
selM1 = sPC
RW = 0
lncPC = 1
LoadMAR = 1

#EXE
selM1 = sPC
RW = 1
selM3 = Rx
selM5 = sM3
