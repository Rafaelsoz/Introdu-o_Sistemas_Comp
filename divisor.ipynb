# %%
num = int(input('numero: '))
div = int(input('divisor: '))
cont = 0
if(num > 0):
  for i in range(0, num, div):
    cont += 1
else:
  for i in range(num, 0, div):
    cont -= 1

if(num + (div * cont)) < num:
  cont += 1
  
print(f'{cont}')
